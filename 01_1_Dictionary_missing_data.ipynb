# %% [markdown]
# # 01_1 — Manually validated technical parameters
#
# **Input:** national development plans and promoter repositories (consulted manually)
# **Output:** `Dictionary/missing_data.json`
#
# Capacity, voltage, technology and line length are missing for a share of
# early-stage investments. Rather than dropping those records, values for major
# pan-European assets were retrieved from national sources and are stored here,
# keyed by Investment ID, so that every manual imputation is auditable and
# separate from the analysis code.

# %%
import pandas as pd
import numpy as np

# %%
missing_data = {
    # 1001: Southern Aegean Interconnector (250 km DC)
    1001: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 500.0, 'Inv_Voltage [kV]': 500.0, 'Inv_Line length [km]': 335.0},
  
    # 1005: ElecLink FR-UK (1 GW / 1000 MW, Eurotunnel)
    1005: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 320.0},
    
    # 1020: Greenwire spur 1 (500 MW)
    1020: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 500.0, 'Inv_Voltage [kV]': 320.0},
    
    # 1021: Greenwire spur 2 (1000 MW)
    1021: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 320.0},
    
    # 1024-1032: Irish-Scottish Isles (ISLES Project)
    1024: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 320.0},
    1025: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 320.0},
    1026: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 320.0},
    1027: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 320.0},
    1028: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 320.0},
    1029: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 320.0},
    1030: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 320.0},
    1031: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 320.0},
    1032: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 320.0},
    
    # 1033: NorthConnect (Norway-GB)
    1033: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1400.0, 'Inv_Voltage [kV]': 500.0, 'Inv_Line length [km]': 650.0},
    
    # 1036-1037: LitPol Link Stage 1
    1036: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 500.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 0.0},
    1037: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 500.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 0.0},
    
    # 1042: Aegean (Crete-Attica)
    1042: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 537.0, 'Inv_Voltage [kV]': 500.0, 'Inv_Line length [km]': 270.0},
    
    # 1043: Area of Lake Constance (Grid enhancement)
    1043: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 380.0, 'Inv_Line length [km]': 80.0},

    # 1049: Interconnector IT-AT (Terna-APG)
    1049: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 220.0, 'Inv_Line length [km]': 40.0},
    
    # 1054: EuroAsia Interconnector (Israel-Cyprus)
    1054: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 500.0, 'Inv_Line length [km]': 310.0},
    
    # 1071: Würmlach - Somplago (Interconnector IT-AT)
    1071: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 300.0, 'Inv_Voltage [kV]': 220.0, 'Inv_Line length [km]': 35.0},

    # 1038: Alytus Back-to-Back
    1038: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 500.0, 'Inv_Voltage [kV]': 400.0},

    # 1111: FAB Link (Gatica-Indian Queens)
    1111: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},

    # --- PARTIAL DATA: Added ONLY strictly necessary categories and jurisdiction ---
    1039: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0}, 
    1076: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    1099: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    1209: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    1217: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    1222: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    1223: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    1228: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 220.0},

    # 1229: Uprate OHL 220kV Sevilla Ring
    1229: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 220.0},
    
    # 123: Swiss Ellipse - New 400kV sections
    123: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 90.0},
    
    # 1234: Kontek-3 - HVDC Interconnector (Denmark-Germany)
    1234: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 600.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 171.0},
    
    # 1235: Aragon Pumping Hydro Connection
    1235: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 3000.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': np.nan},
    
    # 1239: COBRA-2 - Second HVDC link DK-NL
    1239: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 700.0, 'Inv_Voltage [kV]': 320.0, 'Inv_Line length [km]': 325.0},
    
    # 124: Italy-Switzerland 400kV Upgrade
    124: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 90.0},
    
    # 1242: Bentwisch-Güstrow Upgrade
    1242: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 380.0, 'Inv_Line length [km]': 36.0},
    
    # 1263: RO-RS Interconnection Upgrade
    1263: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 500.0, 'Inv_Voltage [kV]': 400.0},
    
    # 1264: Northern Seas Offshore Grid
    1264: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Line length [km]': np.nan},
    
    # 1266: Bulgaria-Serbia New 400kV line
    1266: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 800.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 85.0},
    
    # 1267: France-Spain Additional Project
    1267: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': np.nan},
    
    # 127: Swiss Ellipse 220kV Upgrade
    127: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 500.0, 'Inv_Voltage [kV]': 220.0, 'Inv_Line length [km]': 30.0},
    
    # 1274: GerPol Power Bridge II - Substation Gubin
    1274: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 0.0},
    
    # 1284: Swiss Roof I Reinforcement
    1284: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 380.0, 'Inv_Line length [km]': 49.0},
    
    # 1285: Swiss Ellipse I New Construction
    1285: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 380.0, 'Inv_Line length [km]': 1.0},
    
    # 1286: Swiss Ellipse I 380kV Reinforcement
    1286: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 380.0, 'Inv_Line length [km]': 124.0},
    
    # 1287: Swiss Roof I Voltage Conversion
    1287: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 380.0, 'Inv_Line length [km]': 45.4},
    
    # 1288: Swiss Roof I 220 to 380kV
    1288: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 380.0, 'Inv_Line length [km]': 87.0},
    
    # 1289: Swiss Ellipse II Golbia Substation
    1289: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1650.0, 'Inv_Voltage [kV]': 380.0, 'Inv_Line length [km]': 0.0},
    
    # 1290: Tessin Network Upgrade
    1290: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 500.0, 'Inv_Voltage [kV]': 220.0},
    
    # 1291: Lake Geneva West Reinforcement
    1291: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 500.0, 'Inv_Voltage [kV]': 220.0, 'Inv_Line length [km]': 17.0},
    
    # 1297: ASEI - Abengoa Southern Europe Interconnection
    1297: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 2000.0},
    
    # 130: Swiss Roof Second Circuit
    130: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 50.0},
    
    # 133: Swiss Roof Upgrade to 400kV
    133: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 180.0},
    
    # 134: Swiss Roof New 400kV sections
    134: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 30.0},

    # 1356: Maali (Shetland-Norway) - Cross-border interconnector
    1356: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 320.0},
    
    # 1369: Greenwire North (HVAC link to HVDC hub)
    1369: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1379: ANAI project (Spain-France-UK) - 2000 MW subsea multiterminal VSC HVDC
    1379: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 2000.0},
    
    # 1386: MAREX UK-Ireland Interconnector
    1386: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 400.0},
    
    # 1387: MAREX (Onshore AC combination in Ireland) - Capacity and voltage derived from main project
    1387: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1500.0, 'Inv_Voltage [kV]': 400.0},
    
    # ISLES Project (Irish Scottish Links on Energy Study)
    1397: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1398: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Line length [km]': 348.0},
    1399: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 140: GerPol Power Bridge (Poland-Germany)
    140:  {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # ISLES Substations and Cables continued
    1400: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation'},
    1401: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1402: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1403: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1404: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 1405: LEG1 - 3000 MW HVDC Submarine cable
    1405: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 3000.0},
    
    1406: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'DC'},
    1408: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 1410: EuroAsia Interconnector (Cyprus, Greece, Israel)
    1410: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 2000.0, 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 1518.0},
    
    # ISLES continued
    1411: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1412: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC'},
    1413: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1414: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1415: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1416: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC'},

    # 1048: ALEGrO / Herderen to Lixhe (BE internal reinforcement for ALEGrO)
    1048: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    
    # 1068: Bescano-Santa Llogaia (Internal Spain)
    1068: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1112: Saedinenie OHL (Internal Bulgaria)
    1112: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1113: MAREX (UK-IE Subsea VSC Cable)
    1113: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1500.0},
    
    # 1117: Baltic Synchronization (B2B construction -> DC)
    1117: {'Project_Jurisdiction': 'Cross-border', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 500.0, 'Inv_Voltage [kV]': 330.0}, 
    
    # 122: Swiss Ellipse (Voltage upgrade 225kV into 400kV, 120km)
    122: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 120.0},
    
    # 1220: Network upgrade Central Serbia (400kV AC)
    1220: {'Project_Jurisdiction': 'Internal', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 220.0},
    
    # 126: Swiss Ellipse (New 2x 400kV cable connection Golbia-Robbia)
    126: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1260: Swiss Ellipse II (Voltage increase)
    1260: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Capacity [MW]': 1650.0, 'Inv_Voltage [kV]': 380.0},
    
    # 1261: Swiss Roof (Voltage conversion -> Upgrade)
    1261: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Voltage [kV]': 380.0},
    
    # 129: Swiss Roof (Upgrade of existing 65km OHL to 400kV)
    129: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 65.0},
    
    # 1388: ElecLink (1000MW HVDC Eurotunnel)
    1388: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Capacity [MW]': 1000.0},
    
    # ==========================================
    # --- ISLES PROJECT ---
    # ==========================================
    1389: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC'},
    1390: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC'},
    1391: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 1392: Argyll-Coleraine (101 km, 1 GW subsea cable)
    1392: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Line length [km]': 101.0},
    
    # 1393: Coolkeeragh hub to shore (43km offshore + 10km onshore) 
    1393: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Line length [km]': 53.0},
    
    # 1394: Coleraine-Coolkeeragh (41km, 1 GW subsea DC cable)
    1394: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Line length [km]': 41.0},
    
    1395: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 1396: Coleraine-Coolkeeragh (53km, 500 MW subsea DC cable)
    1396: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 500.0, 'Inv_Line length [km]': 53.0},

    # --- ISLES final segments ---
    1423: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1424: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1425: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1426: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC'},
    1427: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'DC'},

    # 1435, 1436: Southern Aegean Interconnector (Kandeliousa-Syrna/Pergousa). Internal Greece.
    1435: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    1436: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    
    # 1437: Britib project (UK-FR-ES)
    1437: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1800.0, 'Inv_Voltage [kV]': 500.0, 'Inv_Line length [km]': 1330.0},
    
    # 1438: Gallant (Scotland-Northern Ireland. Both UK, thus internal jurisdiction)
    1438: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 1439, 1440: Greenwire South/North (Wales-Ireland HVDC)
    1439: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1440: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 1441: Greenwire South (onshore link)
    1441: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 1442 - 1446: Greenwire South AC links
    1442: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    1443: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    1444: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    1445: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    1446: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    
    # 1447: Greenwire North (onshore link)
    1447: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 1448 - 1450: Greenwire North AC links
    1448: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    1449: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    1450: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    
    # 1453: Greenconnect (subsea HVDC Wales-Ireland)
    1453: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 1454: Greenwire Loop (onshore underground link Ireland)
    1454: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable'},
    
    # 1455: Navarra-Basque Country (Internal Spain)
    1455: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1456: Belgian Backbone (HTLS upgrade standardizzato)
    1456: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    
    # 1457: Concept DE-CH
    1457: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Voltage [kV]': 380.0},
    
    # 1460: Güstrow - Wolmirstedt 380kV (Internal DE)
    1460: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    
    # 1475: Herbertingen - Tiengen (Internal DE)
    1475: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Voltage [kV]': 380.0},
    
    # 1477: Wullenstetten (DE-AT)
    1477: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Cross-border', 'Inv_Voltage [kV]': 380.0},
    
    # 1485: OWP Northsea Part 4 (Offshore DE)
    1485: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Environment': 'Offshore', 'Inv_Voltage [kV]': 380.0},
    
    # 1487: ElecLink (tunnel Channel)
    1487: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 380.0},
    
    # 1492: GerPol Improvements (PST is an onshore substation element)
    1492: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Phase Shift Transformer', 'Inv_Voltage [kV]': 380.0},
    
    # 1500, 1501: SK-HU phase 1 (400kV OHL)
    1500: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    1501: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1510, 1512: Conneforde-Merzen (Internal DE)
    1510: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Voltage [kV]': 380.0},
    1512: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Voltage [kV]': 380.0},
    
    # 1513: OWP TenneT Northsea Part 2 (Offshore DE)
    1513: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Environment': 'Offshore', 'Inv_Voltage [kV]': 380.0},
    
    # 1529: Study to upgrade interconnection DE-NL (PST is an onshore substation element)
    1529: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Phase Shift Transformer', 'Inv_Voltage [kV]': 380.0},
    
    # 1530: Upgrading BA-HR 400kV line
    1530: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1531: Upgrading BA-HR 400kV substation (Substation element)
    1531: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1541: Reinforcements Ring NL phase II
    1541: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    
    # 1542, 1543, 1545: NL internal connections
    1542: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line'},
    1543: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    1545: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal'},
    
    # 1546: NoordWest380 NL
    1546: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0, 'Inv_Capacity [MW]': 2645.0},
# 1556: Prati (IT) – Steinach (AT)
    1556: {'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 132.0},
    
    # 1558: Slovenia-Hungary/Croatia interconnection
    1558: {'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 80.0},
    
    # 1560: Reinforcements Ring NL phase I
    1560: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Voltage [kV]': 380.0},
    
    # 1564, 1567: Baltics synchro with CE 
    1564: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal'},
    1567: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal'},
    
    # 1569, 1570: Baltics synchro with CE (LCC converter)
    1569: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation'},
    1570: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation'},
    
    # 1613, 1627: Offshore Wind Baltic Sea (II)
    1613: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Environment': 'Offshore', 'Inv_Voltage [kV]': 320.0},
    1627: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Environment': 'Offshore', 'Inv_Voltage [kV]': 220.0},
    
    # 1614, 1615, 1617: Upgrade of 220 kV lines in Slovenia to 400 kV
    1614: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Voltage [kV]': 500.0},
    1615: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Voltage [kV]': 500.0},
    1617: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Voltage [kV]': 400.0},
    
    # 1616: Italy-Slovenia DC underground
    1616: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Element_Category': 'Cable/Line', 'Inv_Voltage [kV]': 500.0},
    
    # 1619: LEG1 (2000 MW subsea interconnector)
    1619: {'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Capacity [MW]': 2000.0, 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    
    # 1624: South Balkan Corridor
    1624: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Environment': 'Onshore', 'Inv_Voltage [kV]': 400.0},
    
    # 1631, 1636: AT, SI, IT - South-East Alps Project
    1631: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Voltage [kV]': 380.0},
    1636: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Voltage [kV]': 380.0},
    
    # 1633, 1635: Baltics synchro with CE
    1633: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Voltage [kV]': 330.0},
    1635: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Voltage [kV]': 330.0},
    
    # 1637: Greenlink
    1637: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 1639 - 1649: MaresConnect
    1639: {'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 800.0, 'Inv_Voltage [kV]': 275.0},
    1640: {'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 750.0, 'Inv_Voltage [kV]': 320.0},
    1641: {'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 750.0, 'Inv_Voltage [kV]': 320.0},
    1647: {'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 400.0, 'Inv_Voltage [kV]': 245.0},
    1648: {'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 400.0, 'Inv_Voltage [kV]': 245.0},
    1649: {'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Phase Shift Transformer', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 245.0, 'Inv_Capacity [MW]': 400.0},
    
    # 1673, 1674: GerPol Power Bridge II
    1673: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    1674: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1684: Reinforcement Northwestern DE
    1684: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0, 'Inv_Line length [km]': 35.0},
    
    # 1685, 1686: Wahle-Mecklar & Dollern-Stade
    1685: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0, 'Inv_Line length [km]': 14.0},
    1686: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0, 'Inv_Line length [km]': 210.0},
    
    # 1687, 1690: GREGY Interconnector
    1687: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 500.0},
    1690: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 500.0},
    
    # 1694, 1695: Offshore wind integration LT
    1694: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 330.0},
    1695: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 330.0},
    
    # 1711: CZ Northwest-South corridor (Upgrade substation)
    1711: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1712: CZ Northwest-South corridor (New substation)
    1712: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1718, 1719: Croatian south connection (Substations)
    1718: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    1719: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 1721: Tessin Magadino
    1721: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    
    # 1722: HVDC CentraLink
    1722: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 2000.0},
    
    # 1723, 1724, 1725: Croatian south connection lines
    1723: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    1724: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 220.0},
    1725: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 220.0},
    
    # 1729, 1730: Reactive compensation in Finland
    1729: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Grid Support Equipment', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Reactive Compensation Device', 'Inv_Technology[AC/DC]': 'AC'},
    1730: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Grid Support Equipment', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Reactive Compensation Device', 'Inv_Technology[AC/DC]': 'AC'},
    
    # 1731: ZuidWest380 West
    1731: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    
    # 1733, 1734: Swiss Ellipse I
    1733: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    1734: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    
    # 1745, 1749: LAG Interconnector
    1745: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 2000.0, 'Inv_Voltage [kV]': 400.0},
    1749: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 2000.0, 'Inv_Voltage [kV]': 400.0},
    
    # 1746, 1747, 1748: Crete-North Greece-North Macedonia-Bulgaria Interconnector
    1746: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 2000.0, 'Inv_Voltage [kV]': 525.0},
    1747: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 2000.0, 'Inv_Voltage [kV]': 525.0},
    1748: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 2000.0, 'Inv_Voltage [kV]': 525.0},
    
    # 177: N-S Eastern DE_central section 
    177: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC'},
    
    # 1871: PST Riddes
    1871: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Grid Support Equipment', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Phase Shift Transformer', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 220.0},
    
    # 195: Offshore Wind Baltic Sea
    195: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    
    # 1964: Hybrid Interconnector Denmark-Germany
    1964: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Element type': 'Subsea Cable', 'Inv_Capacity [MW]': 3000.0, 'Inv_Voltage [kV]': 525.0},
    
    # 2025: Baltic Hub
    2025: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    
    # 2026: Malta-Italy Cable Interconnector No.3
    2026: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 200.0, 'Inv_Voltage [kV]': 320.0},
    
    # 2027: Grid Connection System offshore
    2027: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC'},
    
    # 2045: Latvia and Lithuania SSSC
    2045: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Grid Support Equipment', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Reactive Compensation Device', 'Inv_Technology[AC/DC]': 'AC'},
    
    # 2046: Central Western Italy Substation
    2046: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    
    # ==========================================
    # GREEN ENERGY CORRIDOR (Phase 1 & 2)
    # ==========================================
    2047: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    2048: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    2049: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    2050: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    2051: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    2052: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    2053: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    
    # 2054: New 400kV interconnection BA-ME
    2054: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},


    # 2076, 2077, 2078: HTLS in Lyonnais (Internal FR)
    2076: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC'},
    2077: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC'},
    2078: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC'},
    
    # 2079: HVAC reinforcement in Occitania (Internal FR)
    2079: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC'},
    
    # 36: New HVDC (VSC) bipolar interconnection ES-FR
    36: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 320.0},
    
    # 368: LitPol Link Stage 1 Ełk to PL-LT border (Internal section of Poland)
    368: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 369: Construction of new 400 kV line Siedlce Ujrzanów - Miłosna
    369: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 503: New 220kV JM Oriol-New Oriol -Arenales-Caceres 
    503: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 220.0},
    
    # 504: New Arenales substation
    504: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC'},
    
    # 505, 506: Converter stations per la HVDC 320kV ES-FR
    505: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 320.0},
    506: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 320.0},
    
    # 508, 509, 524: Nuove sottostazioni a 400kV (Spagna)
    508: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    509: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    524: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 606: Gramme-Van Eyck Part 1: second 380kV circuit
    606: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 380.0},
    
    # 615: PST a 400kV a Okroglo (Slovenia)
    615: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Grid Support Equipment', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Phase Shift Transformer', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # 621, 622: Converter stations per cavo sottomarino Italia-Montenegro (1000 MW, 500 kV DC)
    621: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 500.0, 'Inv_Line length [km]': 393.0},
    622: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1000.0, 'Inv_Voltage [kV]': 500.0},
    
    # 68: OHL 400kV cross-border Okroglo(SI)-Udine(IT) (120 km)
    68: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0, 'Inv_Line length [km]': 120.0},


    # --- ISLES Project Hubs and Cables ---
    1417: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC'},
    1418: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC'},
    1422: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Offshore Hub', 'Inv_Technology[AC/DC]': 'DC'},
    1419: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1421: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1428: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1429: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC'},
    1420: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC'},

    # --- UK Eastern HVDC ---
    1547: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 500.0},
    
    # --- MaresConnect Components ---
    1650: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 245.0, 'Inv_Capacity [MW]': 400.0},
    1651: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 245.0},
    1654: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 245.0},
    1655: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Substation', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Substation', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # --- Interconnectors and Corridors ---
    2028: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Capacity [MW]': 1000.0},
    2029: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Grid Support Equipment', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Phase Shift Transformer', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 220.0},
    2031: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 1400.0},
    2035: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Grid Support Equipment', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Reactive Compensation Device', 'Inv_Technology[AC/DC]': 'AC'},
    
    2055: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    2056: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    
    # --- Major HVDC subsea links ---
    2058: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0, 'Inv_Capacity [MW]': 1200.0},
    2059: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0, 'Inv_Capacity [MW]': 1500.0},
    2064: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0, 'Inv_Capacity [MW]': 1500.0},
    
    # --- Romanian HVDC links ---
    2062: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    2063: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    2066: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    2067: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Underground Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0},
    
    # --- Further Grid Lines ---
    2069: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Capacity [MW]': 2000.0},
    2070: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 400.0},
    2071: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC', 'Inv_Voltage [kV]': 330.0},
    
    2074: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0, 'Inv_Capacity [MW]': 1000.0},
    2075: {'Infr_Type': 'New', 'Project_Jurisdiction': 'Cross-border', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Offshore', 'Inv_Element type': 'Subsea Cable', 'Inv_Technology[AC/DC]': 'DC', 'Inv_Voltage [kV]': 525.0, 'Inv_Capacity [MW]': 1800.0},
    
    # --- France Internal AC Reinforcements ---
    2080: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC'},
    2081: {'Infr_Type': 'Upgrade (New)', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC'},
    2082: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC'},
    2083: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC'},
    2084: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC'},
    2085: {'Infr_Type': 'Upgrade', 'Project_Jurisdiction': 'Internal', 'Inv_Element_Category': 'Cable/Line', 'Inv_Environment': 'Onshore', 'Inv_Element type': 'Overhead Line', 'Inv_Technology[AC/DC]': 'AC'}
}

# %%
# Save the dictionary to the 'dictionary' folder
with open('Dictionary/missing_data.json', 'w') as json_file:
    json.dump(missing_data, json_file, indent=4)
